# %%
2+2+6
# Out:
# 10

# %%
import pandas as pd

# %%
my_list = [2, 4, 9, 8]

# %%
my_series = pd.Series(my_list)

# %%
my_series.sum()
# Out:
# 23

# %%
my_series.describe()
# Out:
# count    4.000000
# mean     5.750000
# std      3.304038
# min      2.000000
# 25%      3.500000
# 50%      6.000000
# 75%      8.250000
# max      9.000000
# dtype: float64

# %%
props = pd.read_csv("https://first-python-notebook.readthedocs.io/_static/committees.csv")

# %%
props.head(1)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
#
#                                       committee_name committee_position
# 0  YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...            SUPPORT

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
contribs = pd.read_csv("https://first-python-notebook.readthedocs.io/_static/contributions.csv")

# %%
contribs.head(6)
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 5                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
# 5              2083796    2016-07-26              VENTURO
#
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
testing = pd.read_csv("committees.csv")

# %%
props.prop_name
# Out:
# 0      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3      PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 5      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 6      PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
# 7      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 8      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 9      PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 10     PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...
# 11     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 12     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 13     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 14     PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...
# 15     PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props[props.prop_name == 'PROPOSITION 061- STATE PRESCRIPTION DRUG PURCHASES. PRICING STANDARDS. INITIATIVE STATUTE.']
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 60  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 61  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 62  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#     ccdc_prop_id                                          prop_name  \
# 60            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 61            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 62            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 60                442                 1379198
# 61                443                 1376791
# 62                444                 1387641
#
#                                        committee_name committee_position
# 60  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...             OPPOSE
# ...

# %%
prop_61 = props[props.prop_name == 'PROPOSITION 061- STATE PRESCRIPTION DRUG PURCHASES. PRICING STANDARDS. INITIATIVE STATUTE.']

# %%
prop_61.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 60  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 61  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 62  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#     ccdc_prop_id                                          prop_name  \
# 60            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 61            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 62            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 60                442                 1379198
# 61                443                 1376791
# 62                444                 1387641
#
#                                        committee_name committee_position
# 60  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...             OPPOSE
# ...

# %%
prop_61.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3 entries, 60 to 62
# Data columns (total 8 columns):
# ocd_prop_id               3 non-null object
# calaccess_prop_id         3 non-null int64
# ccdc_prop_id              3 non-null int64
# prop_name                 3 non-null object
# ccdc_committee_id         3 non-null int64
# calaccess_committee_id    3 non-null int64
# committee_name            3 non-null object
# committee_position        3 non-null object
# dtypes: int64(4), object(4)
# memory usage: 216.0+ bytes

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
finance = pd.merge(prop_61, contribs, on="calaccess_committee_id")

# %%
finance.head(5)
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 1  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 2  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 3  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 4  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#    ccdc_prop_id                                          prop_name  \
# 0            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 1            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 2            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 3            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 4            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                442                 1379198
# ...

# %%
finance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 806 entries, 0 to 805
# Data columns (total 20 columns):
# ocd_prop_id                     806 non-null object
# calaccess_prop_id               806 non-null int64
# ccdc_prop_id                    806 non-null int64
# prop_name                       806 non-null object
# ccdc_committee_id               806 non-null int64
# calaccess_committee_id          806 non-null int64
# committee_name_x                806 non-null object
# committee_position              806 non-null object
# committee_name_y                806 non-null object
# calaccess_filing_id             806 non-null int64
# date_received                   806 non-null object
# contributor_lastname            806 non-null object
# contributor_firstname           672 non-null object
# contributor_city                806 non-null object
# contributor_state               806 non-null object
# contributor_zip                 806 non-null object
# ...

# %%
finance.amount
# Out:
# 0      2880000.00
# 1        10000.00
# 2       160000.00
# 3       160000.00
# 4      1105000.00
# 5        10000.00
# 6      5700000.00
# 7        10000.00
# 8        10000.00
# 9        30000.00
# 10       10000.00
# 11       52000.00
# 12      115000.00
# 13     4150000.00
# 14      115000.00
# 15     4150000.00
# 16      115000.00
# 17       30000.00
# 18       80000.00
# 19     1075000.00
# 20       30000.00
# 21     2800000.00
# 22       80000.00
# 23        2000.00
# 24       30000.00
# 25       80000.00
# 26     4150000.00
# 27       30000.00
# 28      385000.00
# 29      385000.00
#           ...
# 776         50.00
# 777         15.00
# 778         15.00
# 779         15.00
# 780         48.49
# 781         50.00
# 782         25.00
# 783         15.00
# 784         25.00
# 785         15.00
# 786         25.00
# 787         15.00
# 788         25.00
# 789         20.00
# 790         15.00
# 791         50.00
# 792         15.00
# 793         15.00
# 794         50.00
# ...

# %%
finance.amount.sum()
# Out:
# 127314567.25

# %%
finance.committee_position.value_counts()
# Out:
# SUPPORT    695
# OPPOSE     111
# Name: committee_position, dtype: int64

# %%
support = finance[finance.committee_position == 'SUPPORT']

# %%
oppose = finance[finance.committee_position == 'OPPOSE']

# %%
oppose.amount.sum()
# Out:
# 108417232.0

# %%
support.amount.sum()
# Out:
# 18897335.25

# %%
support.amount.sum() / finance.amount.sum()
# Out:
# 0.14843026731491324

# %%
finance.sort_values("amount")
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 654  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 528  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 739  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 456  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 160  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 246  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 364  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 491  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 193  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 765  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 432  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 428  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# ...

# %%
finance.sort_values("amount", ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 47   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 6    ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 35   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 613  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 153  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 40   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 15   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 26   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 13   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 49   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 121  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 30   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# ...

# %%
finance.sort_values("amount", ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 47   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 6    ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 35   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 613  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 153  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#      ccdc_prop_id                                          prop_name  \
# 47             80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 6              80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 35             80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 613            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 153            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 47                 442                 1379198
# ...

# %%
support.sort_values("amount", ascending=False).head()
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 613  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 153  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 121  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 724  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 743  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#      ccdc_prop_id                                          prop_name  \
# 613            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 153            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 121            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 724            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 743            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#      ccdc_committee_id  calaccess_committee_id  \
# 613                443                 1376791
# ...

# %%
oppose.sort_values("amount", ascending=False).head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 47  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 35  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 6   ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 26  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
# 40  ocd-contest/6b264272-925d-4d31-a69f-4543fa63a819            1377343
#
#     ccdc_prop_id                                          prop_name  \
# 47            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 35            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 6             80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 26            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
# 40            80  PROPOSITION 061- STATE PRESCRIPTION DRUG PURCH...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 47                442                 1379198
# ...

# %%
finance.groupby("committee_name_x").amount.sum()
# Out:
# committee_name_x
# CONSUMER WATCHDOG CAMPAIGN - YES ON 61, MAJOR FUNDING BY YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PRICES, WITH MAJOR FUNDING BY AIDS HEALTHCARE FOUNDATION AND CALIFORNIA NURSES ASSOCIATION PAC         1.501660e+05
# NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEPTIVE RX PROPOSITION, A COALITION OF VETERANS DOCTORS PATIENT ADVOCATES SENIORS TAXPAYERS AND MEMBERS OF PHARMACEUTICAL RESEARCH AND MANUFACTURERS OF AMER.    1.084172e+08
# YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PRICES, WITH MAJOR FUNDING BY AIDS HEALTHCARE FOUNDATION AND CALIFORNIA NURSES ASSOCIATION PAC                                                                  1.874717e+07
# Name: amount, dtype: float64

# %%
finance.groupby("committee_name_x").amount.sum().reset_index()
# Out:
#                                     committee_name_x        amount
# 0  CONSUMER WATCHDOG CAMPAIGN - YES ON 61, MAJOR ...  1.501660e+05
# 1  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...  1.084172e+08
# 2  YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PR...  1.874717e+07

# %%
finance.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                     committee_name_x        amount
# 1  NO ON PROP 61 - CALIFORNIANS AGAINST THE DECEP...  1.084172e+08
# 2  YES ON PROP 61, CALIFORNIANS FOR LOWER DRUG PR...  1.874717e+07
# 0  CONSUMER WATCHDOG CAMPAIGN - YES ON 61, MAJOR ...  1.501660e+05

# %%
finance.groupby(["contributor_firstname", "contributor_lastname"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname contributor_lastname  amount
# 311                   PEG               YORKIN  600.00
# 216                   KIT          BLUMENSTEIN  600.00
# 58              CHRISTINE               CURTIS  600.00
# 31                   BETH            CHAPPELLE  500.00
# 320               RANDALL               MARTIN  500.00
# 261                  MARK              WHISLER  460.87
# 183                JOGEON                   HA  400.00
# 145               GREGORY              LINCOLN  400.00
# 22                 AUDREY      SURMACZ-JOHNSON  250.00
# 192                JOSEPH              WOFFORD  250.00
# 322                    RC              MICHLIN  250.00
# 124                  EVAN               HAZARD  240.00
# 270                  MARY               JEBARA  240.00
# 35                BRADLEY                FLOYD  240.00
# 325                  RITA              COLLINS  220.40
# 143               GREGORY                BROWN  217.20
# ...

# %%
finance.groupby(["contributor_firstname", "contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#     contributor_firstname contributor_lastname committee_position  amount
# 311                   PEG               YORKIN            SUPPORT  600.00
# 216                   KIT          BLUMENSTEIN            SUPPORT  600.00
# 58              CHRISTINE               CURTIS            SUPPORT  600.00
# 31                   BETH            CHAPPELLE            SUPPORT  500.00
# 320               RANDALL               MARTIN            SUPPORT  500.00
# 261                  MARK              WHISLER            SUPPORT  460.87
# 183                JOGEON                   HA            SUPPORT  400.00
# 145               GREGORY              LINCOLN            SUPPORT  400.00
# 22                 AUDREY      SURMACZ-JOHNSON            SUPPORT  250.00
# 192                JOSEPH              WOFFORD            SUPPORT  250.00
# 322                    RC              MICHLIN            SUPPORT  250.00
# 124                  EVAN               HAZARD            SUPPORT  240.00
# ...
